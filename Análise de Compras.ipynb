# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/compras.csv")

# %%
df
# Out:
#             id  contrato_id                    tipo      numero  \
# 0     20775058        35959           Termo Aditivo  00001/2019
# 1     20775059        35959  Termo de Apostilamento  00002/2021
# 2     20775091        35959  Termo de Apostilamento  00003/2021
# 3     28704477        97393                Contrato  00002/2021
# 4     37144735        56292           Termo Aditivo  00003/2022
# ...        ...          ...                     ...         ...
# 4998  37152056        34068  Termo de Apostilamento  00002/2022
# 4999  37151937       109805  Termo de Apostilamento  75201/2022
# 5000  37151938       109805  Termo de Apostilamento  75201/2022
# 5001  37151936       109805  Termo de Apostilamento  75201/2022
# 5002  37151939       109805  Termo de Apostilamento  75201/2022
#
#      receita_despesa                                         observacao  \
# 0            Despesa  CONTRATAÇÃO DE SERVIÇOS ESPECIALIZADOSNA GERAÇ...
# ...

# %%
df.shape
# Out:
# (5003, 11)

# %%
df.describe()
# Out:
#                  id    contrato_id       mesref       anoref         valor
# count  5.003000e+03    5003.000000  5003.000000  5003.000000  5.003000e+03
# mean   3.713695e+07   85914.587248     6.600040  2021.894263  2.430455e+06
# std    4.182287e+05   48307.776514     3.411961     2.687029  1.077756e+07
# min    2.077506e+07     473.000000     1.000000  2008.000000 -1.421841e+07
# 25%    3.714645e+07   42524.000000     4.000000  2021.000000  2.600000e+03
# 50%    3.714836e+07   75354.000000     7.000000  2022.000000  1.500000e+04
# 75%    3.715039e+07  129795.000000     9.000000  2023.000000  1.020233e+05
# max    3.715207e+07  156448.000000    12.000000  2037.000000  8.256214e+07

# %%
df.head(10)
# Out:
#          id  contrato_id                    tipo      numero receita_despesa  \
# 0  20775058        35959           Termo Aditivo  00001/2019         Despesa
# 1  20775059        35959  Termo de Apostilamento  00002/2021         Despesa
# 2  20775091        35959  Termo de Apostilamento  00003/2021         Despesa
# 3  28704477        97393                Contrato  00002/2021         Despesa
# 4  37144735        56292           Termo Aditivo  00003/2022         Despesa
# 5  37144743        56292           Termo Aditivo  00003/2022         Despesa
# 6  37144740        56292           Termo Aditivo  00003/2022         Despesa
# 7  37144736        56292           Termo Aditivo  00003/2022         Despesa
# 8  37144723       156235                Contrato  00015/2022         Despesa
# 9  37144728       156235                Contrato  00015/2022         Despesa
#
#                                           observacao  mesref  anoref  \
# ...

# %%
df.tail(10)
# Out:
#             id  contrato_id                    tipo      numero  \
# 4993  37151941       109805  Termo de Apostilamento  75201/2022
# 4994  37151942       109805  Termo de Apostilamento  75201/2022
# 4995  37151932       109805  Termo de Apostilamento  75201/2022
# 4996  37151943       109805  Termo de Apostilamento  75201/2022
# 4997  37152055        34068  Termo de Apostilamento  00002/2022
# 4998  37152056        34068  Termo de Apostilamento  00002/2022
# 4999  37151937       109805  Termo de Apostilamento  75201/2022
# 5000  37151938       109805  Termo de Apostilamento  75201/2022
# 5001  37151936       109805  Termo de Apostilamento  75201/2022
# 5002  37151939       109805  Termo de Apostilamento  75201/2022
#
#      receita_despesa                                         observacao  \
# 4993         Despesa  REPACTUACAO DO VALOR DO CONTRATIO PARA MANUTEN...
# 4994         Despesa  REPACTUACAO DO VALOR DO CONTRATIO PARA MANUTEN...
# ...

# %%
df['tipo'].values
# Out:
# array(['Termo Aditivo', 'Termo de Apostilamento',
#        'Termo de Apostilamento', ..., 'Termo de Apostilamento',
#        'Termo de Apostilamento', 'Termo de Apostilamento'], dtype=object)

# %%
sns.countplot(df['tipo'])
# Out:
# C:\Users\fabia\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tipo', ylabel='count'>

# %%
plt.figure(figsize = (10, 5))
chart = sns.countplot(
    df['tipo'],
    palette = 'Set1'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
chart.set_title("Compras por Tipo")
# Out:
# C:\Users\fabia\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Compras por Tipo')

# %%
df['anoref'].values
# Out:
# array([2022, 2022, 2022, ..., 2023, 2023, 2023], dtype=int64)

# %%
df['anoref'].unique()
# Out:
# array([2022, 2021, 2023, 2017, 2019, 2020, 2018, 2024, 2025, 2026, 2016,
#        2010, 2013, 2011, 2014, 2012, 2027, 2008, 2015, 2009, 2030, 2029,
#        2032, 2031, 2034, 2033, 2036, 2037, 2028, 2035], dtype=int64)

# %%
plt.figure(figsize = (10, 5))
chart = sns.countplot(
    data = df[df['anoref'] == 2022],
    x = 'tipo',
    palette = 'Set1'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 270)
chart.set_title("Compras por Tipo - Ano 2022");

# %%
plt.figure(figsize = (10, 5))
chart = sns.countplot(
    data = df[df['anoref'] == 2021],
    x = 'tipo',
    palette = 'Set1'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
chart.set_title("Compras por Tipo - Ano 2021");

# %%
plt.figure(figsize = (10, 5))
chart = sns.countplot(
    data = df[df['anoref'] == 2023],
    x = 'tipo',
    palette = 'Set1'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
chart.set_title("Compras por Tipo - Ano 2023");

# %%
df['receita_despesa'].unique()
# Out:
# array(['Despesa', 'Receita'], dtype=object)

# %%
plt.figure(figsize = (10, 5))
chart = sns.countplot(
    data = df[df['anoref'] == 2021],
    x = 'receita_despesa',    
    palette = 'Set1'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
chart.set_title("Receita / Despesa - Ano 2021");

# %%
plt.figure(figsize = (10, 5))
chart = sns.countplot(
    data = df[df['anoref'] == 2022],
    x = 'receita_despesa',
    palette = 'Set1'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
chart.set_title("Receita / Despesa - Ano 2022");

# %%
plt.figure(figsize = (10, 5))
chart = sns.countplot(
    data = df[df['anoref'] == 2023],
    x = 'receita_despesa',
    palette = 'Set1'
)
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
chart.set_title("Receita / Despesa - Ano 2023");

# %%
filtra_despesa = df[df['receita_despesa'] == 'Despesa']
filtra_despesa['valor'].sum()
# Out:
# 12155678063.74

# %%
filtra_receita = df[df['receita_despesa'] == 'Receita']
filtra_receita['valor'].sum()
# Out:
# 3890036.8399999994

# %%
filtra_despesa
# Out:
#             id  contrato_id                    tipo      numero  \
# 0     20775058        35959           Termo Aditivo  00001/2019
# 1     20775059        35959  Termo de Apostilamento  00002/2021
# 2     20775091        35959  Termo de Apostilamento  00003/2021
# 3     28704477        97393                Contrato  00002/2021
# 4     37144735        56292           Termo Aditivo  00003/2022
# ...        ...          ...                     ...         ...
# 4998  37152056        34068  Termo de Apostilamento  00002/2022
# 4999  37151937       109805  Termo de Apostilamento  75201/2022
# 5000  37151938       109805  Termo de Apostilamento  75201/2022
# 5001  37151936       109805  Termo de Apostilamento  75201/2022
# 5002  37151939       109805  Termo de Apostilamento  75201/2022
#
#      receita_despesa                                         observacao  \
# 0            Despesa  CONTRATAÇÃO DE SERVIÇOS ESPECIALIZADOSNA GERAÇ...
# ...

# %%
filtra_receita
# Out:
#             id  contrato_id           tipo      numero receita_despesa  \
# 519   37145734       138128      Concessão  01712/2017         Receita
# 522   37145731       138128      Concessão  01712/2017         Receita
# 523   37145735       138128      Concessão  01712/2017         Receita
# 525   37145733       138128      Concessão  01712/2017         Receita
# 526   37145736       138128      Concessão  01712/2017         Receita
# ...        ...          ...            ...         ...             ...
# 4271  37151148        91788  Termo Aditivo  00002/2022         Receita
# 4272  37151146        91788  Termo Aditivo  00002/2022         Receita
# 4273  37151147        91788  Termo Aditivo  00002/2022         Receita
# 4278  37151149        91788  Termo Aditivo  00002/2022         Receita
# 4465  37151150        91788  Termo Aditivo  00002/2022         Receita
#
#                                              observacao  mesref  anoref  \
# ...

# %%
filtra_despesa['retroativo'].unique()
# Out:
# array(['Não', 'Sim'], dtype=object)

# %%
grupo_despesa = filtra_despesa.groupby(['retroativo', 'tipo'])
grupo_despesa.first()
# Out:
#                                          id  contrato_id        numero  \
# retroativo tipo
# Não        Comodato                37148426       156364    00029/2022
#            Contrato                28704477        97393    00002/2021
#            Credenciamento          37145327       156321    00031/2022
#            Empenho                 37148059       156359  2022NE000154
#            Outros                  37145100       156026    00003/2022
#            Termo Aditivo           20775058        35959    00001/2019
#            Termo de Adesão         37150210       156412    00012/2022
#            Termo de Apostilamento  20775059        35959    00002/2021
# Sim        Termo Aditivo           37146696       152908    00001/2022
#            Termo de Apostilamento  37145084         3085    00003/2022
#
#                                   receita_despesa  \
# retroativo tipo
# Não        Comodato                       Despesa
# ...

# %%
grupo_receita = filtra_receita.groupby(['retroativo', 'tipo'])
grupo_receita.first()
# Out:
#                                 id  contrato_id      numero receita_despesa  \
# retroativo tipo
# Não        Concessão      37145734       138128  01712/2017         Receita
#            Contrato       37145653       156081  00045/2022         Receita
#            Termo Aditivo  37145749       138128  00001/2018         Receita
#
#                                                                  observacao  \
# retroativo tipo
# Não        Concessão      CELEBRAÇÃO DO CONTRATO: 01712/2017 DE ACORDO C...
#            Contrato       CELEBRAÇÃO DO CONTRATO: 00045/2022 DE ACORDO C...
#            Termo Aditivo  PRIMEIRO ADITAMENTO DE PRAZO DO CONTRATO DE CO...
#
#                           mesref  anoref  vencimento    valor
# retroativo tipo
# Não        Concessão           7    2017  2017-08-01   123.33
#            Contrato            8    2022  2022-09-01  1622.04
#            Termo Aditivo      10    2018  2018-11-01   123.33
